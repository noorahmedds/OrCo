# %%
import importlib

from dataloader.data_utils import *

import torch
import torch.nn as nn
import utils

# Load default args
import pickle
file = open("default_args.obj",'rb')
args = pickle.load(file)
file.close()

args.gpu = "1"
args.num_gpu = utils.set_gpu(args)
# Out:
# use gpu: [1]

# %%
from PIL import Image

from tqdm import tqdm

import umap

from sklearn.neighbors import KNeighborsClassifier

from copy import deepcopy

# calculating the pairwise distance between each prototype
from sklearn.metrics.pairwise import cosine_similarity

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from matplotlib.collections import LineCollection
from matplotlib.patches import Patch
import math
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# /BS/fscil/work/envs/fscil_env/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /BS/fscil/work/envs/fscil_env/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
cub_model_dirs = {
    "sup_con": "checkpoint/cub200/base_mixup_contrastive_sr/baseline6.0-mixup-joint_label_smoothing_test+1024_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_128-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session_pretrain_acc_0.78.pth",
    "ce": "checkpoint/cub200/base_supcon_multi/cross_entropy_test_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_256-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session_pretrain_acc_0.77.pth",
    "ce+mixup+ls": "checkpoint/cub200/base_mixup/exp_ls+mixup_search_ft_dot-ft_dot-data_init-start_0/Epo_200-Lr_0.1000-Step_40-Gam_0.10-Bs_128-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.95-ma_0.30/session0_81_244.pth"
}

# %%
def load_model(model, model_dir):
    if model_dir is not None:
        best_model_dict = {}
        if model_dir.endswith(".ckpt"):
            solo_dict = torch.load(model_dir)["state_dict"]
            for k,v in solo_dict.items():
                if "backbone" in k:
                    best_model_dict[k.replace("backbone", "module.encoder")] = v
        else:
            print('Loading init parameters from: %s' % model_dir)
            best_model_dict = torch.load(model_dir)['params']
                    
    return best_model_dict

def compute_knn_score(embedding, labels, model, base_testloader):
    # Compute knn score for the backbone. 
    neigh = KNeighborsClassifier(n_neighbors=3)
    neigh.fit(embedding.cpu(), labels.cpu())
    val_embedding, val_labels = loader_to_embeddings(model, base_testloader)
    score = neigh.score(val_embedding.cpu(), val_labels.cpu())
    print(f"Base Class Validation Accuracy usign KNN: {score*100:.3f}")

# %%
# Load cub200
args.dataset = "cub200"
args.sup_con_feat_dim = 512
args.incremental_on_supcon_head = False
args.nesterov_new = False
args.fine_tune_backbone_joint = False
args.joint_loss = "ce_even"

def init_base_session_model(args, model_dir, project="base_supcon_multi"):
    # Added arguments that had to be separately added to the argument namespace
    MYNET = importlib.import_module('models.%s.Network' % (project)).MYNET
    helper = importlib.import_module('models.%s.helper' % (project))

    args = set_up_datasets(args)

    model = MYNET(args, mode=args.base_mode, writer = None)
    model = nn.DataParallel(model, list(range(args.num_gpu)))
    model = model.cuda()

    cub_model_dir = model_dir
    best_model_dict = load_model(model, cub_model_dir)
    
    # Base Session loading + base prototype generation
    base_set, base_trainloader, base_testloader = get_base_dataloader(args)
    model.load_state_dict(best_model_dict, strict = True)
    out = helper.get_base_fc(base_set, base_testloader.dataset.transform, model, args, return_embeddings=True)
    best_prototypes_cub = out[0]
    
    if "supcon" in project:
        model.module.fc.classifiers[0].weight.data = best_prototypes_cub
        
    best_model_dict = deepcopy(model.state_dict())
    
    return model, best_model_dict, helper

# %%
def get_n_logits(model, n, args, session="base", space="joint"):
    sess = 1
    if session == "base":
        trainset, trainloader, testloader = get_base_dataloader(args)
        classes = torch.arange(args.base_class)
    elif session == "novel":
        # Get first session novel classes
        trainset, trainloader, testloader = get_new_dataloader(args, session = sess)
        assert n <= args.way, print("n must be smaller than then number of shots in the incremental session")
        classes = torch.arange(args.base_class, args.base_class + args.way * sess)
    
    # Sample the classes
    torch.manual_seed(0)
    sampled_classes = (classes[torch.randperm(classes.shape[0])])[:n]
    
    # Now for these sampled classes get the logits
    logits_list = []
    label_list = []
    with torch.no_grad():
        tqdm_gen = tqdm(trainloader)
        for _, batch in enumerate(tqdm_gen, 1):
            data, label = [_.cuda() for _ in batch]
            
            # Filtered_idxs
            idxs = torch.argwhere(torch.isin(label, sampled_classes.cuda())).flatten()
                
            # Skip if no indices this batch for the sampled class
            if idxs.numel() == 0:
                continue
            
            label = label[idxs, ...]
            data = data[idxs, ...]            
            
            # Get logits for all classes up until the 
            embedding = model.module.encode(data)
            logits = model.module.fc.get_logits(embedding)
            
            # Filter our the required labels
            logits_list.append(logits.cpu())
            label_list.append(label.cpu())

        logits_list = torch.cat(logits_list, dim=0)
        label_list = torch.cat(label_list, dim=0)
    
    # Now visualise the logits
    # Average logits for each class
    class_wise_logits = []
    avg_labels = []
    for index in sampled_classes:
        class_index = (label_list == index).nonzero()
        logits_this = logits_list[class_index.squeeze(-1)]
        logits_this = logits_this.mean(0, keepdims=True)
        class_wise_logits.append(logits_this)
        avg_labels.append(index.item())
        
    class_wise_logits = torch.cat(class_wise_logits, dim = 0).cpu().numpy()
    
    return class_wise_logits, avg_labels
    
def draw_logit_map(class_wise_logits, avg_labels, args, subtitle=None):
    # Generate colors for each row
    colors = np.arange(len(class_wise_logits))
    cmap = plt.cm.rainbow
    normalize = Normalize(vmin=0, vmax=class_wise_logits.shape[0] - 1)

    # Plotting
    fig, ax = plt.subplots()
    # Set background color for a range of columns
    start_col = args.base_class
    end_col = class_wise_logits.shape[1]
    novel_color = 'lightcoral'
    base_color = 'lightblue'
    ax.axvspan(start_col, end_col + 0.5, color=novel_color, alpha=0.3)
    ax.axvspan(0, start_col, color=base_color, alpha=0.3)

    # Plotting
    lines = []
    colors = ["red", "blue", "magenta"]
    for i, row in enumerate(class_wise_logits):
#         row_color = plt.cm.rainbow(avg_labels[i])
        row_color = colors[i]
        ax.plot(row, c=row_color, linewidth = 0.7)
    #     ax.text(avg_labels[i]-1, class_wise_logits.max(), avg_labels[i], va='bottom')
        row_text = f"{avg_labels[i]}"
        if avg_labels[i] == row.argmax():
            row_text += " ✓"
        else:
            row_text += " ✖"
        ax.text(avg_labels[i]-1, row[avg_labels[i]], row_text, va='bottom', c=row_color)
    #     ax.vlines(avg_labels[i], class_wise_logits.min(), class_wise_logits.max(), linewidth=0.5, colors=plt.cm.rainbow(avg_labels[i]))

    # ax.text(end_col, class_wise_logits.min(), "Novel Class Logits", rotation = 90, va="bottom")

    # Create a colorbar manually
    #     sm = plt.cm.ScalarMappable(cmap=cmap, norm=normalize)
    #     sm.set_array(colors)
    #     cbar = plt.colorbar(sm)
    #     cbar.set_label('Class')
    legend_elements = [Patch(facecolor=base_color,
                             label='Base Logits', alpha = 0.3),
                       Patch(facecolor=novel_color,
                             label='Novel Logits', alpha = 0.3)
                      ]
    ax.legend(handles=legend_elements, loc='best')

    plt.xlabel('Classes')
    plt.ylabel('Logit Value')
    plt.suptitle('Logit Map Visualisation')
    if subtitle is not None:
        plt.title(subtitle, fontsize=10)
    plt.show()

def test_model(model, testloader):
    vl, va, vaNovel, vaBase, vhm, vam, vbin = model.module.test_fc_head(model.module.fc, testloader, 0, 1)
    s = (f"Top 1 Acc: {va*100:.3f}, "
        f"N/j Acc: {vaNovel*100:.3f}, "
        f"B/j Acc: {vaBase*100:.3f}, "
        f"Binary Accuracy: {vbin*100:.3f}")
    print(s)

# %%
model, best_model_dict, helper = init_base_session_model(args, cub_model_dirs["sup_con"])

# %% [markdown]
# ## Baseline: Random Initialisation without novel session

# %%
trainset, trainloader, testloader = get_new_dataloader(args, session = 1)
# Random init + with novel session
args.not_data_init = True
args.skip_novel = True
model.load_state_dict(best_model_dict, strict = True)
model.module.update_fc(trainloader, testloader, np.unique(trainset.targets), 1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.15it/s]

# %%
logits, labels = get_n_logits(model, 3, args, session="base")
draw_logit_map(logits, labels, args, subtitle="Average Base Class Logits (with Random initialisation of Novel Classifier)")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.00it/s]

# %%
logits, labels = get_n_logits(model, 3, args, session="novel")
draw_logit_map(logits, labels, args, subtitle="Average Base Class Logits (with Random initialisation of Novel Classifier)")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.53s/it]

# %%
test_model(model, testloader)
# Out:
# Top 1 Acc: 69.406, N/j Acc: 0.000, B/j Acc: 77.692, Binary Accuracy: 89.500

# %% [markdown]
# It is important to notice now what this logit map visualises. Note the following classes are sampled from the base classes: 19, 44, 93.
#
# The marked labels on top of the lines represent the maximum value for the average logits for that class with the current model.
#
# For the blue line you can see that the maximum logit occurs on line 19. A checkmark next to the logit number represents that this will be correctly classified using cross entropy.

# %% [markdown]
# # Section 1: BNCE and Visualisation

# %% [markdown]
# ## Random Initialisation followed by novel session

# %%
model, best_model_dict, helper = init_base_session_model(args)
# Out:
# Loading init parameters from: checkpoint/cub200/base_mixup_contrastive_sr/baseline6.0-mixup-joint_label_smoothing_test+1024_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_128-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session_pretrain_acc_0.78.pth
# Generating Features: : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.77it/s]

# %%
trainset, trainloader, testloader = get_new_dataloader(args, session = 1)
# Random init + with novel session
args.not_data_init = True
args.skip_novel = False
model.load_state_dict(best_model_dict, strict = True)
model.module.update_fc(trainloader, testloader, np.unique(trainset.targets), 1)
# Out:
# Top 1 Acc: 69.406, N/j Acc: 0.000, B/j Acc: 77.692, Binary Accuracy: 89.500
# (Novel) Session 1, current_loss 17.599, train_acc 0.000, Average Logit Gap -1505.678, ALGb/n 758.441/147.165:   2%|█▉                                                                                                                 | 1/60 [00:04<04:18,  4.38s/it]
# Top 1 Acc: 69.406, N/j Acc: 0.000, B/j Acc: 77.692, Binary Accuracy: 89.500
# (Novel) Session 1, current_loss 3.760, train_acc 6.000, Average Logit Gap -891.572, ALGb/n 807.572/348.575:  10%|███████████▋                                                                                                         | 6/60 [00:12<02:08,  2.38s/it]
# Top 1 Acc: 67.799, N/j Acc: 46.173, B/j Acc: 70.588, Binary Accuracy: 83.515
# ...

# %%
logits, labels = get_n_logits(model, 3, args, session="base")
draw_logit_map(logits, labels, args, subtitle="Average Base Class Logits (with Random initialisation of Novel Classifier after Novel Phase)")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.45it/s]

# %%
logits, labels = get_n_logits(model, 3, args, session="novel")
draw_logit_map(logits, labels, args, subtitle="Average Novel Class Logits (with Random initialisation of Novel Classifier after Novel Phase)")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.11it/s]

# %% [markdown]
# ## Followed by Joint Session

# %%
joint_set, jointloader = get_jointloader(args, 1)
args.joint_loss = "ce_even"

# %%
model.module.update_fc_joint(jointloader, testloader, np.unique(joint_set.targets), 1)
# Out:
# (Joint) Sess: 1, loss 14.030, trainAcc 86.488, testAcc 69.982, bestHM 70.593, b/n=70.726/66.216, ALG 470.890, ALGb/n 1519.232/2035.599:  26%|██████████████████████▌                                                                | 26/100 [02:05<05:56,  4.82s/it]

# %%
logits, labels = get_n_logits(model, 3, args, session="base")
draw_logit_map(logits, labels, args, subtitle="Average Base Class Logits (with Random initialisation of Novel Classifier after Novel+Joint Phase)")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:04<00:00,  5.56it/s]

# %%
logits, labels = get_n_logits(model, 3, args, session="novel")
draw_logit_map(logits, labels, args, subtitle="Average Novel Class Logits (with Random initialisation of Novel Classifier after Novel+Joint Phase)")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]

# %% [markdown]
# # Section 2: Base classifier/Pretraining scheme

# %%
# Visualise embedding of base classifier 
    # 1. Base classifier pretrained with Sup Con [x]
    # 2. Base classifier pretrained with CE [x]
    # -- 3. Base classifier pretrained with Mixup + CE 
    
# For the above three compute the accuracy using prototypes [x]
# Also report the knn scores for each

# ---

# Now for our base classifier pretrained with sup con perform the following
# Accuracy with prototypes (Take from previous step, normalised vs unnormalised)
# Accuracy with random initialisation after fine tuning
# Accuracy with prototypes after finetuning

# ---

# Fine tune a classifier for 10 epochs ontop of supcon and ce and compare the accuracies

# %%
# Visualise embeddings of base classifier

# %%
# Out:
# '../../datasets/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg'

# %%
pil_image = Image.open(base_set.data[0])

# %%
samples = {} # label against image
for c in np.unique(targets):
    ix = np.argwhere(targets == c).flatten()
    choice = np.random.choice(ix)
    samples[c] = base_set.data[choice]

# %%
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)

# %%
def vis_umap(embedding_list, labels_list, dataset = None):
    data = umap.UMAP(n_components=2).fit_transform(embedding_list.cpu())
    num_classes = len(torch.unique(labels_list))
    # passing to dataframe
    df = pd.DataFrame()
    df["feat_1"] = data[:, 0]
    df["feat_2"] = data[:, 1]
    df["Y"] = labels_list.cpu()
    plt.figure(figsize=(9, 9))
    ax = sns.scatterplot(
        x="feat_1",
        y="feat_2",
        hue="Y",
        palette=sns.color_palette("hls", num_classes),
        data=df,
        legend="full",
        alpha=0.3,
    )
    
    if dataset is not None:
        targets = np.array(base_set.targets)
        samples = {} # label against image
        # select random targets
        selected_targets = np.random.choice(np.unique(targets), size = 20)
        for c in selected_targets:
            ix = np.argwhere(targets == c).flatten()
            choice = np.random.choice(ix)
            samples[c] = base_set.data[choice]
            pil_image = Image.open(samples[c])
            # find x and y coordinate of class c
            row_ix = df.index[df['Y'] == c].tolist()
            row = df.iloc[row_ix[0]]
            x = row["feat_1"]
            y = row["feat_2"]
            imagebox = OffsetImage(pil_image, zoom = 0.1, alpha = 0.6)
            ab = AnnotationBbox(imagebox, (x, y), frameon = False)
            ax.add_artist(ab)
    
    ax.set(xlabel="", ylabel="", xticklabels=[], yticklabels=[])
    ax.tick_params(left=False, right=False, bottom=False, top=False)
    if num_classes > 100:
        anchor = (0.5, 1.8)
    else:
        anchor = (0.5, 1.35)
    plt.legend(loc="upper center", bbox_to_anchor=anchor, ncol=math.ceil(num_classes / 10))
    plt.tight_layout()

# %%
def load_model(model, model_dir):
    if model_dir is not None:
        best_model_dict = {}
        if model_dir.endswith(".ckpt"):
            solo_dict = torch.load(model_dir)["state_dict"]
            for k,v in solo_dict.items():
                if "backbone" in k:
                    best_model_dict[k.replace("backbone", "module.encoder")] = v
        else:
            print('Loading init parameters from: %s' % model_dir)
            best_model_dict = torch.load(model_dir)['params']
                    
    return best_model_dict

def loader_to_embeddings(model, loader):
    embedding_list = []
    label_list = []
    og_mode = model.module.mode
    with torch.no_grad():
        tqdm_gen = tqdm(loader)
        tqdm_gen.set_description("Computing Embeddings: ")
        for i, batch in enumerate(tqdm_gen, 1):
            data, label = [_.cuda() for _ in batch]
            model.module.mode = 'encoder'
            embedding = model(data)
            embedding_list.append(embedding)
            label_list.append(label)
    
    model.module.mode = og_mode
    embedding_list = torch.cat(embedding_list, dim=0)
    label_list = torch.cat(label_list, dim=0)

    return embedding_list, label_list

def set_to_embeddings(model, trainset, transform):
    loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=128,
                                              num_workers=8, pin_memory=True, shuffle=False)
    loader.dataset.transform = transform
    
    embedding_list = []
    label_list = []
    og_mode = model.module.mode
    with torch.no_grad():
        tqdm_gen = tqdm(loader)
        tqdm_gen.set_description("Computing Embeddings: ")
        for i, batch in enumerate(tqdm_gen, 1):
            data, label = [_.cuda() for _ in batch]
            model.module.mode = 'encoder'
            embedding = model(data)
            embedding_list.append(embedding)
            label_list.append(label)
    
    model.module.mode = og_mode
    embedding_list = torch.cat(embedding_list, dim=0)
    label_list = torch.cat(label_list, dim=0)

    return embedding_list, label_list

def test(model, fc, base_testloader):
    # test model using the base test set
    out = model.module.test_fc(fc, base_testloader, 0, 0)
    va = out[1]
    print(f"Base Class Validation Accuracy = {va*100:.3f}")

# %%
# Get base loader to get compute embeddings
base_set, base_trainloader, base_testloader = get_base_dataloader(args)

# %% [markdown]
# ### Supervised Contrastive Learning Model

# %%
# Now loading first the sup con model
model, best_model_dict, helper = init_base_session_model(args, cub_model_dirs["sup_con"])
# Out:
# Loading init parameters from: checkpoint/cub200/base_mixup_contrastive_sr/baseline6.0-mixup-joint_label_smoothing_test+1024_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_128-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session_pretrain_acc_0.78.pth
# Generating Features: : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:25<00:00,  1.08s/it]

# %%
embedding_list, label_list = set_to_embeddings(model, base_set, base_testloader.dataset.transform)
# Out:
# Computing Embeddings: : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:40<00:00,  1.68s/it]

# %%
vis_umap(embedding_list, label_list, base_set)

# %%
# Get accuracy on the validation set for the base model with prototypes
prototypes = helper.get_base_fc(base_set, base_testloader.dataset.transform, model, args)
# Out:
# Generating Features: : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.55it/s]

# %%
test(model, prototypes, base_testloader)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  8.28it/s]
# Base Class Validation Accuracy = 77.692

# %%
compute_knn_score(embedding_list, label_list, model, base_testloader)
# Out:
# Computing Embeddings: : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  8.77it/s]
# Base Class Validation Accuracy usign KNN: 73.394

# %%
# Now for our base classifier pretrained with sup con perform the following
# 1. Accuracy with prototypes (Take from previous step, normalised vs unnormalised)
# 2. Accuracy with random initialisation after fine tuning
# 3. Accuracy with prototypes after finetuning

# Random initialise the base classifier, train for 10 epochs and see result
def fine_tune(model, prototype=None):
    base_classifier = nn.Linear(512, 100) # Base classifier
    if prototype is not none:
        #

# %%
# TODO:

# %% [markdown]
# ### Cross Entropy Trained Model

# %%
# Now loading first the sup con model
# Set ce pretrain specific models
args.ce_pretrain = True
args.sup_con_feat_dim = 128
args.use_sup_con_head = False
model, best_model_dict, helper = init_base_session_model(args, cub_model_dirs["ce"])
# Out:
# Loading init parameters from: checkpoint/cub200/base_supcon_multi/cross_entropy_test_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_256-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session_pretrain_acc_0.77.pth
# Generating Features: : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.39it/s]

# %%
embedding_list, label_list = set_to_embeddings(model, base_set, base_testloader.dataset.transform)
# Out:
# Computing Embeddings: : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.38it/s]

# %%
vis_umap(embedding_list, label_list)

# %%
# Get accuracy on the validation set for the base model with prototypes
prototypes = helper.get_base_fc(base_set, base_testloader.dataset.transform, model, args)
# Out:
# Generating Features: : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  6.59it/s]

# %%
test(model, prototypes, base_testloader)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  7.78it/s]
# Base Class Validation Accuracy = 76.849

# %%
compute_knn_score(embedding_list, label_list, model, base_testloader)
# Out:
# Computing Embeddings: : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  7.83it/s]
# Base Class Validation Accuracy usign KNN: 76.781

# %%
# Get a random vector set of 100 vectors

# %%
base_prototypes = torch.rand(10,15)

# %%
rv = nn.Linear(15,10)

# %%
# concat both and append only rv

# %%
import torch.nn.functional as F

# %%
def optimise_rv(base_prototypes, rv):
    optimizer = torch.optim.SGD(rv,lr=0.01, momentum=0.9, dampening=0.9, weight_decay=0)
    for epoch in range(0,10):
#         cos_sim = F.cosine_similarity(x, y, dim=2)
        F.cosine_similarity(base_prototypes[None,:,:], base_prototypes[:,None,:], dim=-1)

# %%
class FixedSphericalSimplexLinear(torch.nn.Module):
    def __init__(self, in_features, out_features, base_prototypes, radius=1.):
        super().__init__()
        self.radius = radius

        def normalize(x): 
            x = x / torch.norm(x, dim=1, p=2, keepdim=True)
            x = x*self.radius
            return x

        points = torch.randn(out_features, in_features)
        points = normalize(points)
        points = torch.nn.Parameter(points)
        
        base_prototypes = normalize(base_prototypes)

        opt = torch.optim.SGD([points], lr=0.00001)
        
        # Add base prototypes to the rest of the calculations

        tqdm_gen = tqdm(range(1000))
        for _ in tqdm_gen:
            # Combining prototypes but only optimising the reserve vector
            comb = torch.cat((points, base_prototypes.T), axis = 1)
            
            # Add axis in 2nd and on 1st axis and subtract. Then get norm.
            l = (comb.unsqueeze(1) - comb.unsqueeze(0)).norm(p=2, dim=-1)
            l = torch.triu(l, diagonal=1)
            l = (1 / l.sum())
    
            tqdm_gen.set_description(f"Loss = {l:.5f}")
    
            l.backward()
            
            opt.step()
    
            points.data = normalize(points.data)

        self.register_buffer('weight', points.data)

    def forward(self, x):
        return torch.nn.functional.linear(x, self.weight)

# %%
x = FixedSphericalSimplexLinear(10, 15, base_prototypes)
# Out:
# ...
# Loss = 0.00633:  21%|███████████████████████████████▉                                                                                                                         | 209/1000 [00:00<00:01, 400.28it/s]
# ...
# ...
# Loss = 0.00633:  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊         | 940/1000 [00:02<00:00, 390.40it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
base_prototypes.shape
# Out:
# torch.Size([10, 15])

# %%
class FixedSphericalSimplexLinear(torch.nn.Module):
    def __init__(self, in_features, out_features, base_prototypes, radius=1.):
        super().__init__()
        self.radius = radius
        self.temperature = 1.0
        def normalize(x): 
            x = x / torch.norm(x, dim=1, p=2, keepdim=True)
            x = x*self.radius
            return x
        
        # out_features = number of new classes
        # in_features = dimension size of the hypersphere
        points = torch.randn(out_features, in_features)
        points = normalize(points)
        points = torch.nn.Parameter(points)
        
        base_prototypes = normalize(base_prototypes)

        opt = torch.optim.SGD([points], lr=0.1)

        tqdm_gen = tqdm(range(1000))
        for _ in tqdm_gen:
            # Combining prototypes but only optimising the reserve vector
            comb = torch.cat((points, base_prototypes), axis = 0)
            
            # for comb compute the cosine similarity
            sim = F.cosine_similarity(comb[None,:,:], comb[:,None,:], dim=-1)
            
            l = torch.log(torch.exp(sim/self.temperature).sum(axis = 1)).sum() / comb.shape[0]
    
            tqdm_gen.set_description(f"Loss = {l:.5f}")
    
            l.backward()
            
            opt.step()
    
            points.data = normalize(points.data)

        self.register_buffer('weight', points.data)

    def forward(self, x):
        return torch.nn.functional.linear(x, self.weight)

# %%
x = FixedSphericalSimplexLinear(15, 10, base_prototypes)
# Out:
#   0%|                                                                                                                                                                                                                                       | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[271], line 1
# ----> 1 x = FixedSphericalSimplexLinear(15, 10, base_prototypes)
#
# Cell In[185], line 24, in FixedSphericalSimplexLinear.__init__(self, in_features, out_features, base_prototypes, radius)
#      21 tqdm_gen = tqdm(range(1000))
#      22 for _ in tqdm_gen:
#      23     # Combining prototypes but only optimising the reserve vector
# ---> 24     comb = torch.cat((points, base_prototypes), axis = 0)
#      26     # for comb compute the cosine similarity
#      27     sim = F.cosine_similarity(comb[None,:,:], comb[:,None,:], dim=-1)
#
# ...

# %% [markdown]
# # Fixed Simplex creation and angle printing

# %%
# Load base_prototypes for the model
model_dir = "/BS/fscil/work/code/CEC-CVPR2021/checkpoint/mini_imagenet/base_supcon_sr/test_2_ft_dot-ft_dot-data_init-start_1/Epo_100-Lr_0.1000-Step_40-Gam_0.10-Bs_128-Mom_0.90-ftLR_0.100-ftnEpoch_60-jEpoch_100-opt_sgd-vm_hm-ls_0.00-ma_0.30/session0_max_acc.pth"
best_model_dict = torch.load(model_dir)["params"]

# %%
base_prototypes = best_model_dict["module.fc.base_fc.weight"]

# %%
compute_angles(normalize(base_prototypes))
# Out:
# (89.770515, 85.42505)

# %%
norm_base_prototypes = normalize(base_prototypes)

# %%
radius = 1.0
temperature = 1

def normalize(x): 
    x = x / torch.norm(x, dim=1, p=2, keepdim=True)
    x = x*radius
    return x

def compute_angles(vectors):
    # Compute angles for each vector with all others from 
    # Compute angles with the closesnt neighbour only
    proto = vectors.cpu().numpy()
    dot = np.matmul(proto, proto.T)
    dot = dot.clip(min=0, max=1)
    theta = np.arccos(dot)
    np.fill_diagonal(theta, np.nan)
    theta = theta[~np.isnan(theta)].reshape(theta.shape[0], theta.shape[1] - 1)
    
    # Compute the mean for the angle to the nearest neighbour
    avg_angle_close = theta.min(axis = 1).mean()
    
    avg_angle = theta.mean()
#     print("Average angle with all other prototypes (deg): ", np.rad2deg(avg_angle))
    
    # Average angle to the nearest neighbour

    return np.rad2deg(avg_angle), np.rad2deg(avg_angle_close)


foo_points = base_prototypes
foo_points = normalize(foo_points)

# points = foo_points.clone()
points = torch.randn(40, 128).cuda()
points = normalize(points)
points = torch.nn.Parameter(points)
opt = torch.optim.SGD([points], lr=0.0001)

tqdm_gen = tqdm(range(10000))
best_angle = 0
for idx, _ in enumerate(tqdm_gen):
    # # Combining prototypes but only optimising the reserve vector
    comb = torch.cat((points, foo_points), axis = 0)
    
    # Compute the cosine similarity.
#     sim = F.cosine_similarity(points[None,:,:], points[:,None,:], dim=-1)
#     l = torch.log(torch.exp(sim/temperature).sum(axis = 1)).sum() / points.shape[0]
    sim = F.cosine_similarity(comb[None,:,:], comb[:,None,:], dim=-1)
    l = torch.log(torch.exp(sim/temperature).sum(axis = 1)).sum() / comb.shape[0]

#     opt.zero_grad()
    l.backward()
    opt.step()
    points.data = normalize(points.data)

    # TODO: Print average angle between all vectors
    # Print all angles vs just base angles vs just reserve angles
    # Print angles with closesnt neighbour
    curr_angle, curr_angle_close = compute_angles(torch.cat((points, foo_points), axis = 0).detach())
    if curr_angle > best_angle: # best angle is the angle with which the separation is maximised
        best_angle = curr_angle
    
    curr_angle_base, curr_angle_base_close = compute_angles(foo_points)
#     curr_angle_novel, curr_angle_novel_close = compute_angles(points)
    
    tqdm_gen.set_description(f"Loss = {l:.5f}, Best Avg Angle [all]: {best_angle:.3f}, Average Angle rv+base [close]: {curr_angle_close:.3f}, Avg Angle Base [close]: {curr_angle_base_close:.3f}")



# Setting Reserved vectors
# self.rv = points.data
# self.register_buffer('rv', points.data)
# Out:
# Loss = 4.61749, Best Avg Angle [all]: 88.777, Average Angle rv+base [close]: 79.430, Avg Angle Base [close]: 85.425:  29%|█████████████████████████████▌                                                                       | 2932/10000 [00:06<00:16, 422.23it/s]
# Exception ignored in: <function tqdm.__del__ at 0x7f4d82da2ee0>
# Traceback (most recent call last):
#   File "/BS/fscil/work/envs/fscil_env/lib/python3.9/site-packages/tqdm/std.py", line 1144, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[384], line 66
#      63     curr_angle_base, curr_angle_base_close = compute_angles(foo_points)
#      64 #     curr_angle_novel, curr_angle_novel_close = compute_angles(points)
# ...

# %%
compute_angles(points.data)
# Out:
# Average angle with all other prototypes (deg):  89.51694

# %%
radius = 1.0
temperature = 1

def normalize(x): 
    x = x / torch.norm(x, dim=1, p=2, keepdim=True)
    x = x*radius
    return x

def compute_angles(vectors):
    # Compute angles for each vector with all others from 
    # Compute angles with the closesnt neighbour only
    proto = vectors.cpu().numpy()
    dot = np.matmul(proto, proto.T)
    dot = dot.clip(min=0, max=1)
    theta = np.arccos(dot)
    np.fill_diagonal(theta, np.nan)
    theta = theta[~np.isnan(theta)].reshape(theta.shape[0], theta.shape[1] - 1)
    
    # Compute the mean for the angle to the nearest neighbour
    avg_angle_close = theta.min(axis = 1).mean()
    
    avg_angle = theta.mean()
#     print("Average angle with all other prototypes (deg): ", np.rad2deg(avg_angle))
    
    # Average angle to the nearest neighbour

    return np.rad2deg(avg_angle), np.rad2deg(avg_angle_close)


# foo_points = base_prototypes
# foo_points = normalize(foo_points)

# points = foo_points.clone()
points = torch.randn(100, 128).cuda()
points = normalize(points)
points = torch.nn.Parameter(points)
opt = torch.optim.SGD([points], lr=1)

tqdm_gen = tqdm(range(1000))
best_angle = 0
for idx, _ in enumerate(tqdm_gen):
    # # Combining prototypes but only optimising the reserve vector
#     comb = torch.cat((points, foo_points), axis = 0)
    
    # Compute the cosine similarity.
    sim = F.cosine_similarity(points[None,:,:], points[:,None,:], dim=-1)
    l = torch.log(torch.exp(sim/temperature).sum(axis = 1)).sum() / points.shape[0]
#     sim = F.cosine_similarity(comb[None,:,:], comb[:,None,:], dim=-1)
#     l = torch.log(torch.exp(sim/temperature).sum(axis = 1)).sum() / comb.shape[0]

#     opt.zero_grad()
    l.backward()
    opt.step()
    points.data = normalize(points.data)

    # TODO: Print average angle between all vectors
    # Print all angles vs just base angles vs just reserve angles
    # Print angles with closesnt neighbour
#     curr_angle, curr_angle_close = compute_angles(torch.cat((points, foo_points), axis = 0).detach())
    curr_angle, curr_angle_close = compute_angles(points.detach())
    if curr_angle > best_angle: # best angle is the angle with which the separation is maximised
        best_angle = curr_angle
    
#     curr_angle_base, curr_angle_base_close = compute_angles(foo_points)
#     curr_angle_novel, curr_angle_novel_close = compute_angles(points)
    
    tqdm_gen.set_description(f"Loss = {l:.5f}, Best Avg Angle [all]: {best_angle:.3f}, Average Angle rv [close]: {curr_angle_close:.3f}")



# Setting Reserved vectors
# self.rv = points.data
# self.register_buffer('rv', points.data)
# Out:
# Loss = 4.61238, Best Avg Angle [all]: 90.000, Average Angle rv [close]: 90.000: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 312.87it/s]

# %%
all_idx = np.arange(10)

# %%
el = np.arange(4)

# %%
np.isin(all_idx, el, invert=True)
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#         True])

# %%
solo_dict = torch.load("/BS/fscil/work/code/solo-learn/trained_models/supcon/bmcfpmri/supcon-cifar100-alice+aa+lars-bmcfpmri-ep=999.ckpt")["state_dict"]

# %%
solo_dict["projector.2.weight"].shape
# Out:
# torch.Size([128, 2048])

# %%
y = torch.tensor([1,2,1,1,3,4,5,6])

# %%
x = torch.randn(y.shape[0])

# %%
ix = torch.argwhere(y == 1)

# %%
ix_hat = ix[torch.randperm(ix.shape[0])]

# %%
(x[ix] + x[ix_hat]) / 2
# Out:
# tensor([[ 1.1498],
#         [-1.1209],
#         [ 1.1498]])

# %%
output = []
targets = []
for i in y.unique():
    ix = torch.argwhere(y == i)
    ix_hat = ix[torch.randperm(ix.shape[0])]
    output.append((x[ix] + x[ix_hat]) / 2)

# %%
torch.cat(output)
# Out:
# tensor([[ 1.1498],
#         [-0.1120],
#         [ 0.1409],
#         [-0.0304],
#         [-0.4826],
#         [-0.3919],
#         [-1.4741],
#         [-0.3385]])
